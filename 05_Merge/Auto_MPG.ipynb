# %%
import pandas as pd
import numpy as np

# %%
dataset_url_car1 = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv'
dataset_url_car2 = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv'

car1 = pd.read_csv(dataset_url_car1, sep=',')
car2 = pd.read_csv(dataset_url_car2, sep=',')
car2.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mpg</th>
#       <th>cylinders</th>
#       <th>displacement</th>
#       <th>horsepower</th>
#       <th>weight</th>
#       <th>acceleration</th>
#       <th>model</th>
#       <th>origin</th>
#       <th>car</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>33.0</td>
#       <td>4</td>
#       <td>91</td>
#       <td>53</td>
#       <td>1795</td>
#       <td>17.4</td>
#       <td>76</td>
#       <td>3</td>
#       <td>honda civic</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>20.0</td>
#       <td>6</td>
#       <td>225</td>
#       <td>100</td>
# ...

# %%
car1 = car1.loc[:, 'mpg':'car']
car1.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mpg</th>
#       <th>cylinders</th>
#       <th>displacement</th>
#       <th>horsepower</th>
#       <th>weight</th>
#       <th>acceleration</th>
#       <th>model</th>
#       <th>origin</th>
#       <th>car</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>18.0</td>
#       <td>8</td>
#       <td>307</td>
#       <td>130</td>
#       <td>3504</td>
#       <td>12.0</td>
#       <td>70</td>
#       <td>1</td>
#       <td>chevrolet chevelle malibu</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>15.0</td>
#       <td>8</td>
#       <td>350</td>
#       <td>165</td>
# ...

# %%
car1.shape
car2.shape
# Out:
# (200, 9)

# %%
cars = car1.append(car2)
cars.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mpg</th>
#       <th>cylinders</th>
#       <th>displacement</th>
#       <th>horsepower</th>
#       <th>weight</th>
#       <th>acceleration</th>
#       <th>model</th>
#       <th>origin</th>
#       <th>car</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>18.0</td>
#       <td>8</td>
#       <td>307</td>
#       <td>130</td>
#       <td>3504</td>
#       <td>12.0</td>
#       <td>70</td>
#       <td>1</td>
#       <td>chevrolet chevelle malibu</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>15.0</td>
#       <td>8</td>
#       <td>350</td>
#       <td>165</td>
# ...

# %%
owners = np.random.randint(low=15000, high=73001, size=398, dtype='l')
owners
# Out:
# array([26977, 41302, 63914, 33586, 42434, 30133, 22855, 15121, 37710,
#        43726, 57594, 55919, 48574, 35456, 44033, 66357, 41482, 49384,
#        38664, 63058, 19673, 15280, 30152, 30774, 49967, 21501, 68901,
#        54763, 58572, 45872, 32726, 22799, 24341, 21892, 44439, 52870,
#        31178, 54938, 42860, 54238, 49871, 29242, 56176, 60518, 21782,
#        56989, 38847, 26976, 59690, 55535, 29759, 59413, 34003, 57596,
#        57014, 37371, 26294, 35573, 25565, 40104, 45389, 59667, 32564,
#        48524, 62948, 27321, 44113, 26993, 17335, 63752, 55057, 70510,
#        56369, 48102, 57768, 30903, 32315, 56947, 20729, 30788, 30844,
#        56249, 53842, 56593, 65783, 58484, 50609, 39628, 34759, 57057,
#        27664, 36244, 20237, 51607, 57360, 21450, 43345, 16700, 22142,
#        43466, 72672, 72408, 68270, 31487, 33449, 26898, 36863, 17117,
#        44879, 64192, 21706, 48631, 15095, 63222, 49885, 26304, 71827,
# ...

# %%
cars['owners'] = owners
cars.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>mpg</th>
#       <th>cylinders</th>
#       <th>displacement</th>
#       <th>horsepower</th>
#       <th>weight</th>
#       <th>acceleration</th>
#       <th>model</th>
#       <th>origin</th>
#       <th>car</th>
#       <th>owners</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>18.0</td>
#       <td>8</td>
#       <td>307</td>
#       <td>130</td>
#       <td>3504</td>
#       <td>12.0</td>
#       <td>70</td>
#       <td>1</td>
#       <td>chevrolet chevelle malibu</td>
#       <td>26977</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>15.0</td>
# ...
